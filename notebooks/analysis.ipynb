# %% [markdown]
# # Federated Learning Unlearning Analysis
#
# This notebook provides tools for analyzing the results of federated learning unlearning experiments.
#
# ## Features
# - Load and visualize experiment results
# - Compare different unlearning strategies
# - Analyze training curves and convergence
# - Generate comprehensive reports

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/home/carolinewei/CSM117-Final-Project/results/hyperparam_search_results_20251130_220523.csv")

# %%
df.head()
# Out:
#    run_id                   timestamp  dataset  pruning_ratio  \
# 0       0  2025-11-30T22:06:29.521107  cifar10           0.10
# 1       1  2025-11-30T22:07:46.985562  cifar10           0.15
# 2       2  2025-11-30T22:09:01.908302  cifar10           0.20
# 3       3  2025-11-30T22:10:17.620335  cifar10           0.15
# 4       4  2025-11-30T22:11:24.361771  cifar10           0.15
#
#    importance_threshold  pruning_iterations  forget_weight  retention_weight  \
# 0                   0.5                   2            0.7               0.3
# 1                   0.6                   3            0.5               0.5
# 2                   0.5                   3            0.5               0.5
# 3                   0.5                   3            0.7               0.3
# 4                   0.7                   2            0.3               0.7
#
#    pareto_steps  adaptive_weights  ...  pruning_ratio_actual  \
# 0            10              True  ...              0.004978
# 1            10              True  ...              0.000897
# 2            10              True  ...              0.002429
# 3            15             False  ...              0.002782
# 4            15              True  ...              0.000002
#
#    pareto_frontier_size  phase1_forget_acc  phase1_retain_acc  \
# 0                     6              0.386            0.37600
# 1                     6              0.091            0.11175
# 2                     6              0.347            0.34800
# 3                     6              0.100            0.10950
# 4                     6              0.112            0.09725
#
#    phase2_forget_acc  phase2_retain_acc  phase3_forget_acc  phase3_retain_acc  \
# 0                  0                  0              0.358            0.35550
# 1                  0                  0              0.091            0.11175
# 2                  0                  0              0.311            0.31900
# 3                  0                  0              0.100            0.10950
# 4                  0                  0              0.112            0.09725
#
#     status  error_message
# 0  success            NaN
# 1  success            NaN
# 2  success            NaN
# 3  success            NaN
# 4  success            NaN
#
# [5 rows x 37 columns]
